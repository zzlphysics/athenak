# %%
import athena_read
import matplotlib.pyplot as plt
import re

# 文件路径
mad_af05000 = "/home/zhangzelin/projects/athenak/output/20240929_hip_mad_a-05000_128-128-5_gamma14/torus.user.hst"
mad_af09375 = "/home/zhangzelin/projects/athenak/output/20240929_hip_mad_a-09375_128-128-5_gamma14/torus.user.hst" 
mad_az00000 = "/home/zhangzelin/projects/athenak/output/20240929_hip_mad_a+00000_128-128-5_gamma14/torus.user.hst" 
mad_az05000 = "/home/zhangzelin/projects/athenak/output/20240929_hip_mad_a+05000_128-128-5_gamma14/torus.user.hst"
mad_az09375 = "/home/zhangzelin/projects/athenak/output/20240929_hip_mad_a+09375_128-128-5_gamma14/torus.user.hst"
mad_az09800 = "/home/zhangzelin/projects/athenak/output/20240929_hip_mad_a+09800_128-128-5_gamma14/torus.user.hst"
sane_az05000 = "/home/zhangzelin/projects/athenak/output/20240929_hip_sane_a+05000_128-128-5_gamma13/torus.user.hst"
sane_az09375 = "/home/zhangzelin/projects/athenak/output/20240929_hip_sane_a+09375_128-128-5_gamma13/torus.user.hst"

# 文件列表
files = [mad_af05000, mad_af09375, mad_az00000, mad_az05000, mad_az09375, mad_az09800, sane_az05000, sane_az09375]

# 初始化图表
plt.figure(figsize=(10, 6))

# 遍历每个文件
for file in files:
    # 读取文件
    data = athena_read.hst(file)
    
    # 查找mdot_1.9类似的key
    mdot_key = None
    for key in data.keys():
        if re.match(r'mdot_1\.\d+|mdot_2\.0', key):
            mdot_key = key
            break
    
    if mdot_key:
        # 获取x和y数据
        x_vals = data["time"]
        y_vals = data[mdot_key]
        
        # 绘制图表
        plt.plot(x_vals, y_vals, label=f"{file.split('/')[-2][13:25]} ({mdot_key})")
    else:
        print(f"No matching mdot key found in {file}")

# 添加图例
plt.legend()

# 设置图表标题和轴标签
plt.title("Mdot vs Time")
plt.xlabel("Time")
plt.ylabel("Mdot")

# 显示图表
plt.show()

# %%
import athena_read
import matplotlib.pyplot as plt
import re

# 文件路径
mad_af05000 = "/home/zhangzelin/projects/athenak/output/20240929_hip_mad_a-05000_128-128-5_gamma14/torus.user.hst"
mad_af09375 = "/home/zhangzelin/projects/athenak/output/20240929_hip_mad_a-09375_128-128-5_gamma14/torus.user.hst" 
mad_az00000 = "/home/zhangzelin/projects/athenak/output/20240929_hip_mad_a+00000_128-128-5_gamma14/torus.user.hst" 
mad_az05000 = "/home/zhangzelin/projects/athenak/output/20240929_hip_mad_a+05000_128-128-5_gamma14/torus.user.hst"
mad_az09375 = "/home/zhangzelin/projects/athenak/output/20240929_hip_mad_a+09375_128-128-5_gamma14/torus.user.hst"
mad_az09800 = "/home/zhangzelin/projects/athenak/output/20240929_hip_mad_a+09800_128-128-5_gamma14/torus.user.hst"
sane_az05000 = "/home/zhangzelin/projects/athenak/output/20240929_hip_sane_a+05000_128-128-5_gamma13/torus.user.hst"
sane_az09375 = "/home/zhangzelin/projects/athenak/output/20240929_hip_sane_a+09375_128-128-5_gamma13/torus.user.hst"

# 文件列表
files = [mad_af05000, mad_af09375, mad_az00000, mad_az05000, mad_az09375, mad_az09800, sane_az05000, sane_az09375]

# 初始化图表
plt.figure(figsize=(10, 6))

# 遍历每个文件
for file in files:
    # 读取文件
    data = athena_read.hst(file)
    
    # 查找mdot_1.9类似的key
    mdot_key = None
    for key in data.keys():
        if re.match(r'phi_1\.\d+|phi_2\.0', key):
            mdot_key = key
            break
    
    if mdot_key:
        # 获取x和y数据
        x_vals = data["time"]
        y_vals = data[mdot_key]
        
        # 绘制图表
        plt.plot(x_vals, y_vals, label=f"{file.split('/')[-2][13:25]} ({mdot_key})")
    else:
        print(f"No matching mdot key found in {file}")

# 添加图例
plt.legend()

# 设置图表标题和轴标签
plt.title("Phi_BH vs Time")
plt.xlabel("Time")
plt.ylabel("Mdot")

# 显示图表
plt.show()

# %%
import athena_read
import matplotlib.pyplot as plt
import re
import numpy as np

# 文件路径
mad_af05000 = "/home/zhangzelin/projects/athenak/output/20240929_hip_mad_a-05000_128-128-5_gamma14/torus.user.hst"
mad_af09375 = "/home/zhangzelin/projects/athenak/output/20240929_hip_mad_a-09375_128-128-5_gamma14/torus.user.hst" 
mad_az00000 = "/home/zhangzelin/projects/athenak/output/20240929_hip_mad_a+00000_128-128-5_gamma14/torus.user.hst" 
mad_az05000 = "/home/zhangzelin/projects/athenak/output/20240929_hip_mad_a+05000_128-128-5_gamma14/torus.user.hst"
mad_az09375 = "/home/zhangzelin/projects/athenak/output/20240929_hip_mad_a+09375_128-128-5_gamma14/torus.user.hst"
mad_az09800 = "/home/zhangzelin/projects/athenak/output/20240929_hip_mad_a+09800_128-128-5_gamma14/torus.user.hst"
sane_az05000 = "/home/zhangzelin/projects/athenak/output/20240929_hip_sane_a+05000_128-128-5_gamma13/torus.user.hst"
sane_az09375 = "/home/zhangzelin/projects/athenak/output/20240929_hip_sane_a+09375_128-128-5_gamma13/torus.user.hst"

# 文件列表
files = [mad_af05000, mad_af09375, mad_az00000, mad_az05000, mad_az09375, mad_az09800, sane_az05000, sane_az09375]

# 初始化图表
plt.figure(figsize=(10, 6))

# 遍历每个文件
for file in files:
    # 读取文件
    data = athena_read.hst(file)
    # spin = float(file[6:])/1e4
    # print(spin)
    
    # 查找mdot_1.9类似的key
    mdot_key = None
    for key in data.keys():
        if re.match(r'phi_1\.\d+|phi_2\.0', key):
            mdot_key = key
            break
    
    Phi_key = None
    for key in data.keys():
        if re.match(r'phi_1\.\d+|phi_2\.0', key):
            Phi_key = key
            break
    
    if mdot_key and Phi_key:
        # 获取x和y数据
        x_vals = data["time"]
        y_vals = data[Phi_key]*(np.average(data[mdot_key]))**(-1/2) * (4*np.pi)**0.5
        
        # 绘制图表
        plt.plot(x_vals, y_vals, label=f"{file.split('/')[-2][13:25]} ({mdot_key})")
    else:
        print(f"No matching mdot key found in {file}")

# 添加图例
plt.legend()

# 设置图表标题和轴标签
plt.title("phi vs Time")
plt.xlabel("Time")
plt.ylabel("Mdot")

# 显示图表
plt.show()

# %%
mad_af05000.split('/')[-2][13:]
# Out:
# 'mad_a-05000_128-128-5_gamma14'

# %%
import athena_read
import matplotlib.pyplot as plt
import re

# 文件路径
mad_az09375_5 = "/home/zhangzelin/projects/athenak/output/20241011_hip_mad_a+09375_96-96-5_gamma14/torus.user.hst"
mad_az09375_6 = "/home/zhangzelin/projects/athenak/output/20241011_hip_mad_a+09375_96-96-6_gamma14/torus.user.hst"
mad_az09375_7 = "/home/zhangzelin/projects/athenak/output/20241011_hip_mad_a+09375_96-96-7_gamma14/torus.user.hst"
mad_az09375_8 = "/home/zhangzelin/projects/athenak/output/20241011_hip_mad_a+09375_96-96-8_gamma14/torus.user.hst"

# 文件列表
files = [mad_az09375_5, mad_az09375_6, mad_az09375_7, mad_az09375_8]

# 初始化图表
plt.figure(figsize=(10, 6))

# 遍历每个文件
for file in files:
    # 读取文件
    data = athena_read.hst(file)
    
    # 查找mdot_1.9类似的key
    mdot_key = None
    for key in data.keys():
        if re.match(r'mdot_1\.\d+|mdot_2\.0', key):
            mdot_key = key
            break
    
    if mdot_key:
        # 获取x和y数据
        x_vals = data["time"]
        y_vals = data[mdot_key]
        
        # 绘制图表
        plt.plot(x_vals, y_vals, label=f"{file.split('/')[-2][13:32]} ({mdot_key})")
    else:
        print(f"No matching mdot key found in {file}")

# 添加图例
plt.legend()

# 设置图表标题和轴标签
plt.title("Mdot vs Time")
plt.xlabel("Time")
plt.ylabel("Mdot")

# 显示图表
plt.show()

# %%
import athena_read
import matplotlib.pyplot as plt
import re

# 文件路径
mad_az09375_5 = "/home/zhangzelin/projects/athenak/output/20241011_hip_mad_a+09375_96-96-5_gamma14/torus.user.hst"
mad_az09375_6 = "/home/zhangzelin/projects/athenak/output/20241011_hip_mad_a+09375_96-96-6_gamma14/torus.user.hst"
mad_az09375_7 = "/home/zhangzelin/projects/athenak/output/20241011_hip_mad_a+09375_96-96-7_gamma14/torus.user.hst"
mad_az09375_8 = "/home/zhangzelin/projects/athenak/output/20241011_hip_mad_a+09375_96-96-8_gamma14/torus.user.hst"

# 文件列表
files = [mad_az09375_5, mad_az09375_6, mad_az09375_7, mad_az09375_8]

# 初始化图表
plt.figure(figsize=(10, 6))

# 遍历每个文件
for file in files:
    # 读取文件
    data = athena_read.hst(file)
    
    # 查找mdot_1.9类似的key
    phi_key = None
    for key in data.keys():
        if re.match(r'phi_1\.\d+|phi_2\.0', key):
            phi_key = key
            break
    
    if phi_key:
        # 获取x和y数据
        x_vals = data["time"]
        y_vals = data[phi_key]
        
        # 绘制图表
        plt.plot(x_vals, y_vals, label=f"{file.split('/')[-2][13:32]} ({phi_key})")
    else:
        print(f"No matching mdot key found in {file}")

# 添加图例
plt.legend()

# 设置图表标题和轴标签
plt.title("Phi_BH vs Time")
plt.xlabel("Time")
plt.ylabel("Phi_BH")

# 显示图表
plt.show()

# %%
import athena_read
import matplotlib.pyplot as plt
import re
import numpy as np

# 文件路径
mad_az09375_5 = "/home/zhangzelin/projects/athenak/output/20241011_hip_mad_a+09375_96-96-5_gamma14/torus.user.hst"
mad_az09375_6 = "/home/zhangzelin/projects/athenak/output/20241011_hip_mad_a+09375_96-96-6_gamma14/torus.user.hst"
mad_az09375_7 = "/home/zhangzelin/projects/athenak/output/20241011_hip_mad_a+09375_96-96-7_gamma14/torus.user.hst"
mad_az09375_8 = "/home/zhangzelin/projects/athenak/output/20241011_hip_mad_a+09375_96-96-8_gamma14/torus.user.hst"

# 文件列表
files = [mad_az09375_5, mad_az09375_6, mad_az09375_7, mad_az09375_8]

# 初始化图表
plt.figure(figsize=(10, 6))

# 遍历每个文件
for file in files:
    # 读取文件
    data = athena_read.hst(file)

    mdot_key = None
    for key in data.keys():
        if re.match(r'mdot_1\.\d+|mdot_2\.0', key):
            mdot_key = key
            break
    
    # 查找mdot_1.9类似的key
    phi_key = None
    for key in data.keys():
        if re.match(r'phi_1\.\d+|phi_2\.0', key):
            phi_key = key
            break
    
    if phi_key:
        # 获取x和y数据
        x_vals = data["time"]
        y_vals = data[phi_key] * (data[mdot_key])**-0.5 #* (4*np.pi)**0.5
        
        # 绘制图表
        plt.plot(x_vals, y_vals, label=f"{file.split('/')[-2][13:32]} ({phi_key})")
    else:
        print(f"No matching mdot key found in {file}")

# 添加图例
plt.legend()

# 设置图表标题和轴标签
plt.title("phi vs Time")
plt.xlabel("Time")
plt.ylabel("phi")

# 显示图表
plt.show()

# %%
import athena_read
import matplotlib.pyplot as plt
import re
import numpy as np

# 文件路径
sane_az05000_128_5_10_20 = "/home/data/20240929_hip_sane_a+05000_128-128-5_gamma13/torus.user.hst"
sane_az09375_128_5_10_20 = "/home/data/20240929_hip_sane_a+09375_128-128-5_gamma13/torus.user.hst"
sane_az09375_96_7_10_20 = "/home/zhangzelin/projects/athenak/output/20241113_hip_sane_a+09375_96-96-96-7_gamma13/torus.user.hst"
sane_az05000_192_6_10_20 = "/home/zhangzelin/projects/athenak/output/20241113_hip_sane_a+05000_192-192-192-6_gamma13/torus.user.hst"
sane_az09375_128_4_6_12 = "/home/zhangzelin/projects/athenak/output/20241114_hip_sane_a09375_128-128-128-4_gamma13/torus.user.hst"
sane_az09375_96_4_6_12 = "/home/zhangzelin/projects/athenak/output/20241114_hip_sane_a09375_96-96-96-4_gamma13/torus.user.hst"
# 文件列表
files = [sane_az05000_128_5_10_20, sane_az09375_128_5_10_20, sane_az09375_96_7_10_20, sane_az05000_192_6_10_20, sane_az09375_128_4_6_12, sane_az09375_96_4_6_12]

# 初始化图表
fig0, ax0 = plt.subplots(3,1,figsize=(6, 10))

# 遍历每个文件
for file in files:
    # 读取文件
    data = athena_read.hst(file)

    mdot_key = None
    for key in data.keys():
        if re.match(r'mdot_1\.\d+|mdot_2\.0', key):
            mdot_key = key
            break
    
    # 查找mdot_1.9类似的key
    phi_key = None
    for key in data.keys():
        if re.match(r'phi_1\.\d+|phi_2\.0', key):
            phi_key = key
            break
    
    if mdot_key and phi_key:
        # 获取x和y数据
        x_vals = data["time"]
        mdot_vals = data[mdot_key]
        Phi_vals = data[phi_key]
        phi_vals = Phi_vals * (mdot_vals)**-0.5 #* (4*np.pi)**0.5
        
        # 绘制图表
        ax0[0].plot(x_vals, mdot_vals, label=f"{file.split('/')[-2][13:38]} ({mdot_key})")
        ax0[0].legend()
        # ax0[0].set_xlim(0, 10000)
        ax0[0].set_title("Mdot vs Time")
        ax0[0].set_xlabel("Time")
        ax0[0].set_ylabel("Mdot")
        ax0[1].plot(x_vals, Phi_vals, label=f"{file.split('/')[-2][13:38]} ({phi_key})")
        ax0[1].legend()
        # ax0[1].set_xlim(0, 10000)
        ax0[1].set_title("Phi_BH vs Time")
        ax0[1].set_xlabel("Time")
        ax0[1].set_ylabel("Phi_BH")
        ax0[2].plot(x_vals, phi_vals, label=f"{file.split('/')[-2][13:38]} ({phi_key})")
        ax0[2].legend()
        # ax0[2].set_xlim(0, 10000)
        ax0[2].set_title("phi vs Time")
        ax0[2].set_xlabel("Time")
        ax0[2].set_ylabel("phi")
    else:
        print(f"No matching mdot key found in {file}")

# 显示图表
plt.tight_layout()
plt.show()
