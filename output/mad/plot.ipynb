# %%
# %run /home/zhangzelin/projects/athenak/vis/python/plot_hst.py -i torus.user.hst -v mdot_1.3
# %run /home/zhangzelin/projects/athenak/vis/python/plot_hst.py -i torus.user.hst -v phi_1.3
# Out:
# /home/zhangzelin/projects/athenak/vis/python/athena_read.py:102: UserWarning: Multiple headers found; using most recent data
#   warnings.warn('Multiple headers found; using most recent data')
# {'time': array([ 900.113,  900.225,  900.3  , ..., 7029.23 , 7029.3  , 7029.41 ]), 'dt': array([0.0375, 0.0375, 0.0375, ..., 0.0375, 0.0375, 0.0375]), 'mdot_1.3': array([3.06857e-05, 3.06822e-05, 3.06800e-05, ..., 1.84763e+01,
#        1.84774e+01, 1.84752e+01]), 'edot_1.3': array([-3.38472e-05, -3.38441e-05, -3.38423e-05, ..., -2.51508e+01,
#        -2.39551e+01, -1.53342e+01]), 'ldot_1.3': array([-6.08983e-05, -6.08948e-05, -6.08928e-05, ...,  1.97424e+02,
#         1.97133e+02,  1.97371e+02]), 'phi_1.3': array([2.81634e-05, 2.81830e-05, 2.81959e-05, ..., 6.31282e+01,
#        6.31254e+01, 6.31265e+01]), 'mdot_12.0': array([2.62219e-04, 2.63565e-04, 2.64462e-04, ..., 2.82569e+01,
# ...

# %%
# %run /home/zhangzelin/projects/athenak/vis/python/plot_slice.py -d x -n log --r_max=64 --vmin=1e-9 --vmax=20 --horizon_mask --notex --grid /home/zhangzelin/projects/athenak/output/mad/bin/torus.mhd_w_bcc.01000.bin dens show
# Out:
# min =  9.99999993922529e-09   max =  12.648823738098145

# %%
# %run /home/zhangzelin/projects/athenak/vis/python/plot_slice.py -d x -c jet --r_max=30 --vmin=-3 --vmax=3 --horizon_mask --notex /home/zhangzelin/projects/athenak/output/mad/bin/torus.mhd_w_bcc.00700.bin eint show
# Out:
# min =  7.492499676242659e-11   max =  8.891522407531738

# %%
# %run /home/zhangzelin/projects/athenak/vis/python/plot_slice.py -d x -c "jet" -n log --r_max=1000 --vmin=1e-3 --vmax=1e3 --horizon_mask --notex /home/zhangzelin/projects/athenak/output/mad/bin/torus.mhd_w_bcc.00700.bin derived:beta_inv_rel show
# Out:
# min =  2.2402938261081556e-33   max =  247711644490.04233

# %%
# %run /home/zhangzelin/projects/athenak/vis/python/plot_slice.py -d x -c jet -n log --r_max=1000 --vmin=1e-6 --vmax=1e0 --horizon_mask --notex /home/zhangzelin/projects/athenak/output/mad/bin/torus.mhd_w_bcc.01000.bin derived:sigma_rel show
# Out:
# min =  9.227826873305915e-26   max =  3655421248.343845
